# %% [markdown]
# # Nikita Kiran More(Batch 25 Jan)

# %% [markdown]
# # Descriptive Analytics and Data Preprocessing on Sales & Discounts Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("sales_data_with_discounts.csv")

# %%
print(df.head())
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %%
numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns

# %%
statistics = df[numerical_columns].agg(['mean', 'median', 'std'])

# %%
mode = df[numerical_columns].mode().iloc[0]

# %%
print("Descriptive Statistics for Numerical Columns:")
print(statistics)
# Out:
# Descriptive Statistics for Numerical Columns:
#           Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# mean    5.066667  10453.433333       33812.835556          15.155242
# median  4.000000   1450.000000        5700.000000          16.577766
# std     4.231602  18079.904840       50535.074173           4.220602
#
#         Discount Amount  Net Sales Value
# mean        3346.499424     30466.336131
# median       988.933733      4677.788059
# std         4509.902963     46358.656624

# %%
print("\nMode for Numerical Columns:")
print(mode)
# Out:
# Mode for Numerical Columns:
# Volume                   3.000000
# Avg Price              400.000000
# Total Sales Value    24300.000000
# Discount Rate (%)        5.007822
# Discount Amount         69.177942
# Net Sales Value        326.974801
# Name: 0, dtype: float64

# %%
for col in numerical_columns:
    print(f"\nInterpretation for {col}:")
    print(f"Mean: {statistics.at['mean', col]:.2f}")
    print(f"Median: {statistics.at['median', col]:.2f}")
    print(f"Mode: {mode[col]:.2f}")
    print(f"Standard Deviation: {statistics.at['std', col]:.2f}")
# Out:
# Interpretation for Volume:
# Mean: 5.07
# Median: 4.00
# Mode: 3.00
# Standard Deviation: 4.23
#
# Interpretation for Avg Price:
# Mean: 10453.43
# Median: 1450.00
# Mode: 400.00
# Standard Deviation: 18079.90
#
# Interpretation for Total Sales Value:
# Mean: 33812.84
# Median: 5700.00
# Mode: 24300.00
# Standard Deviation: 50535.07
#
# Interpretation for Discount Rate (%):
# Mean: 15.16
# Median: 16.58
# Mode: 5.01
# Standard Deviation: 4.22
#
# Interpretation for Discount Amount:
# Mean: 3346.50
# Median: 988.93
# Mode: 69.18
# Standard Deviation: 4509.90
#
# Interpretation for Net Sales Value:
# Mean: 30466.34
# Median: 4677.79
# Mode: 326.97
# Standard Deviation: 46358.66

# %% [markdown]
# # 2)Data Visualization

# %% [markdown]
# # ●	Histograms: Plot histograms for each numerical column

# %%
df.hist('Volume')
# Out:
# array([[<Axes: title={'center': 'Volume'}>]], dtype=object)

# %%
df.hist('Avg Price')
# Out:
# array([[<Axes: title={'center': 'Avg Price'}>]], dtype=object)

# %%
df.hist('Total Sales Value')
# Out:
# array([[<Axes: title={'center': 'Total Sales Value'}>]], dtype=object)

# %%
df.hist('Discount Rate (%)')
# Out:
# array([[<Axes: title={'center': 'Discount Rate (%)'}>]], dtype=object)

# %%
df.hist('Discount Amount')
# Out:
# array([[<Axes: title={'center': 'Discount Amount'}>]], dtype=object)

# %%
df.hist('Net Sales Value')
# Out:
# array([[<Axes: title={'center': 'Net Sales Value'}>]], dtype=object)

# %% [markdown]
# # Analyze skewness and outliers for numerical columns

# %%
for col in ['Volume']:
    print(f'Column: {col}')
    print(f'Skewness: {df[col].skew()}')
    
    plt.figure(figsize=(8, 4))
    plt.hist(df[col], bins=20)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# Column: Volume
# Skewness: 2.731723626557714

# %%
for col in ['Avg Price']:
    print(f'Column: {col}')
    print(f'Skewness: {df[col].skew()}')
    
    plt.figure(figsize=(8, 4))
    plt.hist(df[col], bins=20)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# Column: Avg Price
# Skewness: 1.9088730767759727

# %%
for col in ['Total Sales Value']:
    print(f'Column: {col}')
    print(f'Skewness: {df[col].skew()}')
    
    plt.figure(figsize=(8, 4))
    plt.hist(df[col], bins=20)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# Column: Total Sales Value
# Skewness: 1.5347293238977937

# %%
for col in ['Discount Rate (%)']:
    print(f'Column: {col}')
    print(f'Skewness: {df[col].skew()}')
    
    plt.figure(figsize=(8, 4))
    plt.hist(df[col], bins=20)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# Column: Discount Rate (%)
# Skewness: -1.0622943696988825

# %%
for col in ['Discount Amount']:
    print(f'Column: {col}')
    print(f'Skewness: {df[col].skew()}')
    
    plt.figure(figsize=(8, 4))
    plt.hist(df[col], bins=20)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# Column: Discount Amount
# Skewness: 1.9130377339538271

# %%
for col in ['Net Sales Value']:
    print(f'Column: {col}')
    print(f'Skewness: {df[col].skew()}')
    
    plt.figure(figsize=(8, 4))
    plt.hist(df[col], bins=20)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# Column: Net Sales Value
# Skewness: 1.5408217575344376

# %% [markdown]
# # Identify potential outliers using IQR method

# %%
Q1 = df[col].quantile(0.25)
Q3 = df[col].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = df[col][(df[col] < lower_bound) | (df[col] > upper_bound)]
print(f'Potential outliers: {outliers.tolist()} \n')
# Out:
# Potential outliers: [160346.50118040683, 133705.96028100033, 162399.01626686862, 139563.63821492044, 151348.33980554453, 163915.971, 179507.47904902254, 134677.49634229453, 134731.95462498485, 152667.35835357232, 151182.48953316535, 128021.66814052028, 134546.43404201147, 150648.92786553132, 151300.0615012888, 162603.18637944586, 144071.7757958041, 133691.7616807722, 155761.9778062413, 130557.83332702736, 136485.41909127205, 154937.48547454836, 123703.3246326362, 134934.94669153576, 154541.08736469384, 163967.08007046414, 156895.96877157467, 166263.16134784388, 127965.99098759051, 134024.2192588631, 116881.4052796457, 133917.77266654104, 141315.26771941697, 138449.92203904898, 156330.96988962853]

# %% [markdown]
# # Analyze distribution of categorical columns

# %%
for col in ['Day']:
    print(f'Column: {col}')
    print(df[col].value_counts())
    plt.figure(figsize=(8, 4))
    df[col].value_counts().plot(kind='bar')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# Column: Day
# Day
# Thursday     90
# Friday       60
# Saturday     60
# Sunday       60
# Monday       60
# Tuesday      60
# Wednesday    60
# Name: count, dtype: int64

# %%
for col in ['SKU']:
    print(f'Column: {col}')
    print(df[col].value_counts())
    plt.figure(figsize=(8, 4))
    df[col].value_counts().plot(kind='bar')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# Column: SKU
# SKU
# M01    15
# M02    15
# L09    15
# L08    15
# L07    15
# L06    15
# L05    15
# L04    15
# L03    15
# L02    15
# L01    15
# F10    15
# F09    15
# F08    15
# F07    15
# F06    15
# F05    15
# F04    15
# F03    15
# F02    15
# F01    15
# M10    15
# M09    15
# M08    15
# M07    15
# M06    15
# M05    15
# M04    15
# M03    15
# L10    15
# Name: count, dtype: int64

# %%
for col in ['City']:
    print(f'Column: {col}')
    print(df[col].value_counts())
    plt.figure(figsize=(8, 4))
    df[col].value_counts().plot(kind='bar')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# Column: City
# City
# C    450
# Name: count, dtype: int64

# %%
for col in ['BU']:
    print(f'Column: {col}')
    print(df[col].value_counts())
    plt.figure(figsize=(8, 4))
    df[col].value_counts().plot(kind='bar')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# Column: BU
# BU
# Mobiles      150
# FMCG         150
# Lifestyle    150
# Name: count, dtype: int64

# %%
for col in ['Brand']:
    print(f'Column: {col}')
    print(df[col].value_counts())
    plt.figure(figsize=(8, 4))
    df[col].value_counts().plot(kind='bar')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# Column: Brand
# Brand
# Jeera      90
# Gear       60
# Viva       60
# RealU      45
# YouM       45
# Babaji     45
# Vedic      45
# Sumsang    30
# Orange     30
# Name: count, dtype: int64

# %%
for col in ['Model']:
    print(f'Column: {col}')
    print(df[col].value_counts())
    plt.figure(figsize=(8, 4))
    df[col].value_counts().plot(kind='bar')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# Column: Model
# Model
# RU-10             15
# RU-9 Plus         15
# M-Formals         15
# W-Lounge          15
# W-Western         15
# M-Casuals         15
# M-Jeans           15
# W-Inners          15
# W-Casuals         15
# M- Inners         15
# M- T Shirts       15
# Gear BB Cream     15
# Gear Shampoo      15
# Gear Cream        15
# Gear Oil          15
# Vedic Oil         15
# Babaji Cream      15
# Babaji Shampoo    15
# Vedic Shampoo     15
# Vedic Cream       15
# Babaji Oil        15
# O-11              15
# O-10              15
# S-21              15
# S-20              15
# RU-9              15
# YM-98             15
# YM-99 Plus        15
# YM-99             15
# M-Shoes           15
# Name: count, dtype: int64

# %% [markdown]
# # Boxplots:

# %% [markdown]
# # Create boxplots for numerical variables to identify outliers and the interquartile range.

# %%
numerical_cols = ['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']
plt.figure(figsize=(12, 6))
sns.boxplot(data=df[numerical_cols])
plt.title('Boxplots for Numerical Variables')
plt.show()

# %%
plt.tight_layout()
plt.show()

# %%
for col in numerical_columns:
    print(f"\nInterpretation for {col}:")
    print(f"Identifying potential outliers and extreme values for {col}:")
    print(f"Interquartile Range (IQR) can be observed from the boxplot.")
    print(f"Any points outside the whiskers are potential outliers.")
# Out:
# Interpretation for Volume:
# Identifying potential outliers and extreme values for Volume:
# Interquartile Range (IQR) can be observed from the boxplot.
# Any points outside the whiskers are potential outliers.
#
# Interpretation for Avg Price:
# Identifying potential outliers and extreme values for Avg Price:
# Interquartile Range (IQR) can be observed from the boxplot.
# Any points outside the whiskers are potential outliers.
#
# Interpretation for Total Sales Value:
# Identifying potential outliers and extreme values for Total Sales Value:
# Interquartile Range (IQR) can be observed from the boxplot.
# Any points outside the whiskers are potential outliers.
#
# Interpretation for Discount Rate (%):
# Identifying potential outliers and extreme values for Discount Rate (%):
# Interquartile Range (IQR) can be observed from the boxplot.
# Any points outside the whiskers are potential outliers.
#
# Interpretation for Discount Amount:
# ...

# %%
q1 = df[col].quantile(0.25)
q3 = df[col].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)][col]
print(f"Potential outliers: {outliers.values}")
# Out:
# Potential outliers: [160346.50118041 133705.960281   162399.01626687 139563.63821492
#  151348.33980554 163915.971      179507.47904902 134677.49634229
#  134731.95462498 152667.35835357 151182.48953317 128021.66814052
#  134546.43404201 150648.92786553 151300.06150129 162603.18637945
#  144071.7757958  133691.76168077 155761.97780624 130557.83332703
#  136485.41909127 154937.48547455 123703.32463264 134934.94669154
#  154541.08736469 163967.08007046 156895.96877157 166263.16134784
#  127965.99098759 134024.21925886 116881.40527965 133917.77266654
#  141315.26771942 138449.92203905 156330.96988963]

# %% [markdown]
# # ●	Bar Chart Analysis for Categorical Column:

# %% [markdown]
# # 1)Identify categorical columns

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
print("Categorical Columns:", categorical_columns)
# Out:
# Categorical Columns: Index(['Date', 'Day', 'SKU', 'City', 'BU', 'Brand', 'Model'], dtype='object')

# %%
df = pd.read_csv('sales_data_with_discounts.csv')
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %% [markdown]
# # 2)Create bar charts to visualize the frequency or count of each category.
# Analyze the distribution of categories and provide insights.

# %%
for column in categorical_columns:
    plt.figure(figsize=(8, 4))
    df[column].value_counts().plot(kind='bar')
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.xticks(rotation=0)
    plt.show()

# %% [markdown]
# # Standardization of Numerical Variables
# ●	Objective: To scale numerical variables for uniformity, improving the dataset’s suitability for analytical models.
# ●	Steps:
# 	Explain the concept of standardization (z-score normalization).
# 	Standardize the numerical columns using the formula: z=x-mu/sigma

# %% [markdown]
# Standardisation, also known as Z-score normalisation, is a crucial concept in data preprocessing, particularly in machine learning and statistics.
# Technique used to scale the features of a dataset so that they have a mean of 0 and a standard deviation of 1. This transformation ensures that the
# features contribute equally to the model and makes it easier to compare features with different scales.
# This problem is solved by standardisation, which gives each feature a mean of 0 and a standard deviation of 1.
#
# Formula :
#
# z = (x - μ) / σ
#
# where:
#
# z = standardized value,
# x = original value,
# μ = mean of the feature,
# σ = standard deviation of the feature

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
numerical_cols = ['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']
print(numerical_cols)
# Out:
# ['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']

# %%
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# %%
def standardize(x):
    return (x - x.mean()) / x.std()

df[numerical_cols] = df[numerical_cols].apply(standardize)

# %%
print(df[numerical_cols])
# Out:
#        Volume  Avg Price  Total Sales Value  Discount Rate (%)  \
# 0    2.347417   0.091072           2.922469          -0.829365
# 1    1.165831  -0.019548           1.329516          -0.851714
# 2    0.456880   0.312312           1.561038          -1.350129
# 3    0.220563   0.533552           1.717365          -1.947555
# 4   -0.488389  -0.130168          -0.188242           0.672990
# ..        ...        ...                ...                ...
# 445 -0.724706  -0.506277          -0.617647           0.075924
# 446  0.220563  -0.434374          -0.360400           0.450596
# 447 -0.724706  -0.489684          -0.605774           0.902788
# 448 -0.488389  -0.473091          -0.556303           0.388042
# 449 -0.961023  -0.406719          -0.607753           0.042188
#
#      Discount Amount  Net Sales Value
# 0           3.948422         2.801638
# 1           1.846958         1.269613
# 2           1.621190         1.543957
# 3           1.112568         1.763847
# ...

# %%
df.hist(bins=10, figsize=(15, 10), color='blue', alpha=0.7)
plt.suptitle('Before Standardization', fontsize=16)
plt.show()

# %%
scaler = StandardScaler()
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# %%
plt.figure(figsize=(12, 8))
for i, col in enumerate(numerical_cols):
    plt.subplot(2, 3, i+1)
    plt.hist(df[col], bins=50)
    plt.title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Conversion of Categorical Data into Dummy Variables

# %%
df = pd.get_dummies(df,columns=['Date', 'Day', 'SKU', 'City', 'BU', 'Brand', 'Model'])
df
# Out:
#        Volume  Avg Price  Total Sales Value  Discount Rate (%)  \
# 0    2.350029   0.091173           2.925721          -0.830289
# 1    1.167129  -0.019570           1.330995          -0.852661
# 2    0.457388   0.312659           1.562775          -1.351631
# 3    0.220808   0.534146           1.719276          -1.949723
# 4   -0.488932  -0.130313          -0.188452           0.673739
# ..        ...        ...                ...                ...
# 445 -0.725512  -0.506840          -0.618334           0.076009
# 446  0.220808  -0.434857          -0.360801           0.451097
# 447 -0.725512  -0.490229          -0.606448           0.903793
# 448 -0.488932  -0.473617          -0.556923           0.388474
# 449 -0.962092  -0.407171          -0.608429           0.042235
#
#      Discount Amount  Net Sales Value  Date_01-04-2021  Date_02-04-2021  \
# 0           3.952816         2.804756             True            False
# ...

# %%
print(df.head())
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0  2.350029   0.091173           2.925721          -0.830289         3.952816
# 1  1.167129  -0.019570           1.330995          -0.852661         1.849014
# 2  0.457388   0.312659           1.562775          -1.351631         1.622995
# 3  0.220808   0.534146           1.719276          -1.949723         1.113807
# 4 -0.488932  -0.130313          -0.188452           0.673739         0.227852
#
#    Net Sales Value  Date_01-04-2021  Date_02-04-2021  Date_03-04-2021  \
# 0         2.804756             True            False            False
# 1         1.271026             True            False            False
# 2         1.545675             True            False            False
# 3         1.765810             True            False            False
# 4        -0.227595             True            False            False
#
#    Date_04-04-2021  ...  Model_Vedic Cream  Model_Vedic Oil  \
# ...

# %% [markdown]
# # Conclusion

# %% [raw]
# Data preprocessing is a crucial step in data analysis
# and machine learning as it directly influences the
# performance of models. Standardization and one-hot encoding
# are two common preprocessing techniques that ensure data is in
# a suitable format for analysis and modeling.

# %% [raw]
# Standardization involves scaling numerical features
# so they have a mean of zero and a standard deviation
# of one. This is particularly important when dealing
# with algorithms like K-Means clustering and linear
# regression, which are sensitive to the scale of data.
# Standardization ensures that all features contribute
# equally to the model, preventing features with larger
# scales from dominating the model's learning process.

# %% [raw]
# One-hot encoding is a technique used to convert
# categorical variables into a numerical format.
# Many machine learning algorithms cannot directly
# handle categorical data, so one-hot encoding
# transforms these variables into binary vectors.
# Each category becomes a separate binary feature,
# allowing the model to learn from categorical data
# without imposing a false ordinal relationship between
# categories.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
standardized_data = scaler.fit_transform(df)

# %%
print(standardized_data)
# Out:
# [[ 2.35002911  0.091173    2.92572115 ... -0.18569534 -0.18569534
#   -0.18569534]
#  [ 1.16712855 -0.01957016  1.33099521 ... -0.18569534 -0.18569534
#   -0.18569534]
#  [ 0.45738822  0.31265934  1.56277525 ... -0.18569534  5.38516481
#   -0.18569534]
#  ...
#  [-0.72551234 -0.49022863 -0.60644824 ... -0.18569534 -0.18569534
#   -0.18569534]
#  [-0.48893223 -0.47361715 -0.55692259 ... -0.18569534 -0.18569534
#   -0.18569534]
#  [-0.96209245 -0.40717125 -0.60842926 ... -0.18569534 -0.18569534
#   -0.18569534]]

# %% [raw]
# Both techniques help in improving model accuracy and
# robustness. Standardization reduces the likelihood of
# model bias towards certain features, while one-hot
# encoding allows the model to interpret and utilize
# categorical data effectively. By applying these
# preprocessing steps, data is made more consistent
# and meaningful, which enhances the quality of insights
# derived from analysis and improves the predictive power
# of machine learning models.
